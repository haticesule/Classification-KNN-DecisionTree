# %% [markdown]
# Hatice Şule Akın-20040301036

# %% [markdown]
# E-Commerce Shipping Data

# %% [markdown]
# Bu veri seti, bir uluslararası e-ticaret şirketinin elektronik ürünleri için müşteri verilerini içeriyor. Veri seti, 10.999 gözlem ve 12 değişken içeriyor. Değişkenler şunlardır:
#
# ID: Müşteri ID numarası Warehouse block: Depo bloğu Mode of shipment: Sevkiyat yöntemi Customer care calls: Müşteri hizmetleri arama sayısı Customer rating: Müşteri puanı Cost of the product: Ürün fiyatı Prior purchases: Önceki satın alma sayısı Product importance: Ürün önemi Gender: Cinsiyet Discount offered: Sunulan indirim Weight in gms: Ürün ağırlığı Reached on time: Ürün zamanında teslim edildi mi? (1: Hayır, 0: Evet) Bu veri seti, müşteri davranışını ve eğilimlerini anlamanıza yardımcı olabilir. Örneğin, müşteri hizmetlerine yapılan arama sayısının, ürünün zamanında teslim edilip edilmediğiyle nasıl ilişkili olduğunu inceleyebilirsiniz.
#
# Veri setindeki değişkenler, aşağıdaki kategorilere ayrılabilir:
#
# Demografik değişkenler: Cinsiyet ve yaş gibi müşterinin demografik özelliklerini tanımlayan değişkenler. Psikolojik değişkenler: Müşterinin satın alma davranışını etkileyebilecek psikolojik özelliklerini tanımlayan değişkenler. Örneğin, müşteri memnuniyeti ve sadakat. Sosyo-ekonomik değişkenler: Müşterinin sosyo-ekonomik durumunu tanımlayan değişkenler. Örneğin, gelir ve eğitim seviyesi. Ürün özellikleri: Ürünün özelliklerini tanımlayan değişkenler. Örneğin, fiyat ve ağırlık. Satış ve hizmet özellikleri: Satış ve hizmetle ilgili değişkenler. Örneğin, müşteri hizmetleri arama sayısı ve indirimler. Bu veri seti, aşağıdaki analizleri yapmak için kullanılabilir:
#
# Müşteri segmentasyonu: Müşterileri benzer özelliklere göre gruplandırmak. Bu, müşterilere daha alakalı pazarlama mesajları ve teklifleri göndermenize yardımcı olabilir. Müşteri elde tutma analizi: Müşterilerin neden ayrıldığını veya ayrıldığını anlamak. Bu, müşteri bağlılığını artırmanıza yardımcı olabilir. Müşteri yaşam boyu değeri (CLTV) analizi: Her bir müşterinin şirketinize ne kadar değer kattığını tahmin etmek. Bu, pazarlama ve satış çabalarınızı optimize etmenize yardımcı olabilir. Ödevinizde hangi analizleri yapmak istediğinizi ve bu analizlerden ne tür bilgiler elde etmek istediğinizi belirledikten sonra, veri setini analiz etmeye başlayabilirsiniz. Veri setini inceleyerek ve veri ön işleme yaparak başlayın. Ardından, uygun veri madenciliği algoritmalarını seçin ve uygulayın. Son olarak, veri madenciliği sonuçlarını analiz edin ve yorumlayın.
#
# İşte bu veri setini kullanarak yapabileceğiniz bazı spesifik analizler:
#
# Müşteri hizmetleri aramalarının ürün zamanında teslim edilip edilmediğiyle nasıl ilişkili olduğunu inceleyebilirsiniz. Örneğin, müşteri hizmetleri aramalarının sayısının, ürünün zamanında teslim edilmeme olasılığını artırdığını bulabilirsiniz. Bu, müşteri hizmetlerine yapılan çağrıların sayısını azaltmak için stratejiler geliştirmenize yardımcı olabilir. Ürün öneminin, ürünün zamanında teslim edilip edilmediğiyle nasıl ilişkili olduğunu inceleyebilirsiniz. Örneğin, önemli ürünlere sahip müşterilerin, önemsiz ürünlere sahip müşterilere göre ürünün zamanında teslim edilmemesini daha az tolere ettiğini bulabilirsiniz. Bu, önemli ürünlere sahip müşterilere özel hizmetler sunmanıza yardımcı olabilir. Cinsiyetin, ürünün zamanında teslim edilip edilmediğiyle nasıl ilişkili olduğunu inceleyebilirsiniz. Örneğin, erkeklerin, kadınlarına göre ürünün zamanında teslim edilmemesini daha az tolere ettiğini bulabilirsiniz. Bu, erkeklere özel hizmetler sunmanıza yardımcı olabilir. Bu analizler, müşteri davranışını ve eğilimlerini anlamanıza ve şirketinizin performansını iyileştirmenize yardımcı olabilir.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import numpy as np
import seaborn as sns
import itertools
from matplotlib.ticker import NullFormatter
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/Hatice/OneDrive/Masaüstü/Train.csv")
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
df.shape
# Out:
# (10999, 12)

# %%
df.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
df['Reached.on.Time_Y.N'].value_counts()
# Out:
# Reached.on.Time_Y.N
# 1    6563
# 0    4436
# Name: count, dtype: int64

# %%
bins = np.linspace(df.Cost_of_the_Product.min(), df.Cost_of_the_Product.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="Customer_rating", palette="Set1", col_wrap=5)
g.map(plt.hist, 'Cost_of_the_Product', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
df["Mode_of_Shipment"] = df["Mode_of_Shipment"].replace({"Ship": 1, "Flight": 2, "Road": 3})

bins = np.linspace(df.Mode_of_Shipment.min(), df.Mode_of_Shipment.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="Customer_rating", palette="Set1", col_wrap=5)
g.map(plt.hist, 'Mode_of_Shipment', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# #Problem ve Yöntem
# Şirketin müşteri memnuniyetini göz önünde bulundurduğumda düşük puanlı verilere rastlıyorum. Bu şirketin dışarıdan görünümünü ve kalitesini olumsuz etkiler.Müşteri memnunyetsizliğinin sebebini öğrenmek için etkileyecek verilere bakılacak ve ona göre düzenlemelere gidilecek. Bu sorunun kaynağı teslimatın gecikmesinden mi kaynaklanıyor analiz edilecek. Classification yöntemi kullanılacak ve K Nearest Neighbor(KNN), Decision Tree algoritmaları kullanılacak.

# %%
df.groupby(['Gender'])['Reached.on.Time_Y.N'].value_counts(normalize=True)
# Out:
# Gender  Reached.on.Time_Y.N
# F       1                      0.594409
#         0                      0.405591
# M       1                      0.599010
#         0                      0.400990
# Name: proportion, dtype: float64

# %%
df.groupby(['Product_importance'])['Reached.on.Time_Y.N'].value_counts(normalize=True)
# Out:
# Product_importance  Reached.on.Time_Y.N
# high                1                      0.649789
#                     0                      0.350211
# low                 1                      0.592788
#                     0                      0.407212
# medium              1                      0.590450
#                     0                      0.409550
# Name: proportion, dtype: float64

# %%
df['Gender'].replace(to_replace=['M','F'], value=[0,1],inplace=True)
df.head()
# Out:
#    ID Warehouse_block  Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D                 2                    4                2
# 1   2               F                 2                    4                5
# 2   3               A                 2                    2                2
# 3   4               B                 2                    3                3
# 4   5               C                 2                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance  Gender  \
# 0                  177                3                low       1
# 1                  216                2                low       0
# 2                  183                4                low       0
# 3                  176                4             medium       0
# 4                  184                3             medium       1
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
Feature = df[['Mode_of_Shipment',  'Cost_of_the_Product', 'Gender','Reached.on.Time_Y.N']]
Feature = pd.concat([Feature, pd.get_dummies(df['Product_importance'], dtype=int)], axis=1)
Feature.head()
# Out:
#    Mode_of_Shipment  Cost_of_the_Product  Gender  Reached.on.Time_Y.N  high  \
# 0                 2                  177       1                    1     0
# 1                 2                  216       0                    1     0
# 2                 2                  183       0                    1     0
# 3                 2                  176       0                    1     0
# 4                 2                  184       1                    1     0
#
#    low  medium
# 0    1       0
# 1    1       0
# 2    1       0
# 3    0       1
# 4    0       1

# %%
from sklearn.preprocessing import LabelEncoder


df["Warehouse_block"] = df["Warehouse_block"].replace({"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6})
df["Mode_of_Shipment"] = df["Mode_of_Shipment"].replace({"Ship": 1, "Flight": 2, "Road": 3})
df["Product_importance"] = df["Product_importance"].replace({"low": 1, "medium": 2, "high": 3})

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from scipy.stats import ttest_ind

knn_algorithms = [KNeighborsClassifier(n_neighbors=n) for n in range(1, 51)]

dt_algorithms = [DecisionTreeClassifier(max_depth=d) for d in range(1, 51)]

knn_accuracy_list = []
knn_f1_list = []
knn_sensitivity_list = []
knn_specificity_list = []

dt_accuracy_list = []
dt_f1_list = []
dt_sensitivity_list = []
dt_specificity_list = []

for knn_algorithm, dt_algorithm in zip(knn_algorithms, dt_algorithms):
    knn_temp_accuracy, knn_temp_f1, knn_temp_sensitivity, knn_temp_specificity = [], [], [], []
    dt_temp_accuracy, dt_temp_f1, dt_temp_sensitivity, dt_temp_specificity = [], [], [], []

    for _ in range(10):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

        knn_algorithm.fit(X_train, y_train)
        knn_y_pred = knn_algorithm.predict(X_test)
        knn_metrics = metrics.confusion_matrix(y_test, knn_y_pred)
        knn_temp_accuracy.append(metrics.accuracy_score(y_test, knn_y_pred))
        knn_temp_f1.append(metrics.f1_score(y_test, knn_y_pred))
        knn_temp_sensitivity.append(knn_metrics[0, 0] / (knn_metrics[0, 0] + knn_metrics[0, 1]))
        knn_temp_specificity.append(knn_metrics[1, 1] / (knn_metrics[1, 0] + knn_metrics[1, 1]))

        dt_algorithm.fit(X_train, y_train)
        dt_y_pred = dt_algorithm.predict(X_test)
        dt_metrics = metrics.confusion_matrix(y_test, dt_y_pred)
        dt_temp_accuracy.append(metrics.accuracy_score(y_test, dt_y_pred))
        dt_temp_f1.append(metrics.f1_score(y_test, dt_y_pred))
        dt_temp_sensitivity.append(dt_metrics[0, 0] / (dt_metrics[0, 0] + dt_metrics[0, 1]))
        dt_temp_specificity.append(dt_metrics[1, 1] / (dt_metrics[1, 0] + dt_metrics[1, 1]))

    knn_accuracy_list.append(np.mean(knn_temp_accuracy))
    knn_f1_list.append(np.mean(knn_temp_f1))
    knn_sensitivity_list.append(np.mean(knn_temp_sensitivity))
    knn_specificity_list.append(np.mean(knn_temp_specificity))

    dt_accuracy_list.append(np.mean(dt_temp_accuracy))
    dt_f1_list.append(np.mean(dt_temp_f1))
    dt_sensitivity_list.append(np.mean(dt_temp_sensitivity))
    dt_specificity_list.append(np.mean(dt_temp_specificity))


plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(range(1, 51), knn_accuracy_list, 'g', label='Accuracy')
plt.plot(range(1, 51), knn_f1_list, 'b', label='F1')
plt.plot(range(1, 51), knn_sensitivity_list, 'r', label='Sensitivity')
plt.plot(range(1, 51), knn_specificity_list, 'c', label='Specificity')
plt.title('KNN Metrics')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Metrics')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, 51), dt_accuracy_list, 'g', label='Accuracy')
plt.plot(range(1, 51), dt_f1_list, 'b', label='F1')
plt.plot(range(1, 51), dt_sensitivity_list, 'r', label='Sensitivity')
plt.plot(range(1, 51), dt_specificity_list, 'c', label='Specificity')
plt.title('Decision Tree Metrics')
plt.xlabel('Max Depth')
plt.ylabel('Metrics')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(" KNN Accuracy List:")
print(knn_accuracy_list)
print("\nKNN F1 List:")
print(knn_f1_list)
print("\nKNN sensivity list")
print(knn_sensitivity_list)
print("\nKNN Specificity List:")
print(knn_specificity_list)
# Out:
#  KNN Accuracy List:
# [0.6509090909090908, 0.6736363636363636, 0.6636363636363638, 0.6754545454545455, 0.6668181818181819, 0.6768181818181818, 0.6595454545454544, 0.6713636363636365, 0.6590909090909091, 0.6713636363636365, 0.6622727272727272, 0.6713636363636365, 0.6631818181818182, 0.6704545454545453, 0.665, 0.6677272727272727, 0.6668181818181819, 0.6618181818181819, 0.6586363636363636, 0.6640909090909091, 0.6577272727272728, 0.6627272727272728, 0.6545454545454545, 0.6654545454545453, 0.6590909090909091, 0.6686363636363637, 0.6613636363636364, 0.6672727272727272, 0.66, 0.6595454545454544, 0.66, 0.6622727272727272, 0.6640909090909091, 0.665, 0.6613636363636364, 0.665, 0.6595454545454544, 0.6604545454545454, 0.66, 0.66, 0.665, 0.6618181818181819, 0.6636363636363638, 0.6690909090909091, 0.6654545454545453, 0.6677272727272727, 0.6695454545454547, 0.6681818181818182, 0.6672727272727272, 0.6663636363636363]
#
# KNN F1 List:
# ...

# %%
print(" Decision Tree Accuracy List:")
print(dt_accuracy_list)
print("\nDecision Tree F1 List:")
print(dt_f1_list)
print("\nDecision Tree sensivity list")
print(dt_sensitivity_list)
print("\nDecision Tree Specificity List:")
print(dt_specificity_list)
# Out:
#  Decision Tree Accuracy List:
# [0.6890909090909092, 0.6890909090909092, 0.6845454545454546, 0.6859090909090908, 0.6822727272727274, 0.6812272727272728, 0.6751363636363636, 0.672, 0.6732272727272728, 0.6681818181818182, 0.6713181818181818, 0.6700454545454544, 0.6682727272727272, 0.6684090909090908, 0.6656818181818182, 0.6628181818181819, 0.6563636363636365, 0.6486363636363637, 0.6560454545454546, 0.6549545454545455, 0.6495454545454545, 0.6435000000000001, 0.6475454545454544, 0.6488636363636363, 0.6488181818181818, 0.6454090909090909, 0.6426363636363636, 0.6416818181818182, 0.6423181818181819, 0.6398181818181818, 0.6416818181818181, 0.6408636363636364, 0.6407727272727274, 0.6443636363636364, 0.6418636363636363, 0.6407272727272727, 0.6419999999999999, 0.6403636363636364, 0.640590909090909, 0.6415454545454545, 0.6444545454545455, 0.6415909090909092, 0.6401818181818181, 0.6402272727272728, 0.640590909090909, 0.6400454545454546, 0.6393181818181818, 0.6407272727272726, 0.6425, 0.641]
#
# ...

# %%
from scipy.stats import ttest_ind

t_statistic_accuracy, p_value_accuracy = ttest_ind(knn_accuracy_list, dt_accuracy_list)
t_statistic_f1, p_value_f1 = ttest_ind(knn_f1_list, dt_f1_list)
t_statistic_sensitivity, p_value_sensitivity = ttest_ind(knn_sensitivity_list, dt_sensitivity_list)
t_statistic_specificity, p_value_specificity = ttest_ind(knn_specificity_list, dt_specificity_list)

print("\nT-Test for Accuracy:")
print("T-Statistic:", t_statistic_accuracy)
print("P-Value:", p_value_accuracy)

print("\nT-Test for F1 Score:")
print("T-Statistic:", t_statistic_f1)
print("P-Value:", p_value_f1)

print("\nT-Test for Sensitivity:")
print("T-Statistic:", t_statistic_sensitivity)
print("P-Value:", p_value_sensitivity)

print("\nT-Test for Specificity:")
print("T-Statistic:", t_statistic_specificity)
print("P-Value:", p_value_specificity)
# Out:
# T-Test for Accuracy:
# T-Statistic: 4.300201067892595
# P-Value: 4.0355107444699665e-05
#
# T-Test for F1 Score:
# T-Statistic: -1.8073223419450912
# P-Value: 0.07378018918990406
#
# T-Test for Sensitivity:
# T-Statistic: 3.5167419531657798
# P-Value: 0.000663637739549159
#
# T-Test for Specificity:
# T-Statistic: -3.1334074103775844
# P-Value: 0.0022793853522706225

# %% [markdown]
# Accuracy (Doğruluk):
#
# P-değeri 0.05'ten çok küçük (4.0355107444699665e-05), bu yüzden iki algoritmanın accuracy değerleri arasında istatistiksel olarak anlamlı bir fark var.
# T-istatistiği pozitif (4.300201067892595), yani KNN'nin accuracy değeri DT'den daha yüksektir.
#
# F1 Skoru:
#
# P-değeri 0.05'ten büyük (0.07378018918990406), bu yüzden iki algoritmanın F1 skorları arasında istatistiksel olarak anlamlı bir fark yok.
#
# Sensitivity (Duyarlılık):
#
# P-değeri 0.05'ten çok küçük (0.000663637739549159), bu yüzden iki algoritmanın duyarlılık değerleri arasında istatistiksel olarak anlamlı bir fark var.
# T-istatistiği pozitif (3.5167419531657798), yani KNN'nin duyarlılık değeri DT'den daha yüksektir.
#
# Specificity (Özgüllük):
#
# P-değeri 0.05'ten küçük (0.0022793853522706225), bu yüzden iki algoritmanın özgüllük değerleri arasında istatistiksel olarak anlamlı bir fark var.
# T-istatistiği negatif (-3.1334074103775844), yani KNN'nin özgüllük değeri DT'den daha düşüktür.
#
# Sonuçlar ve Çıkarımlar:
#
# Accuracy ve duyarlılık açısından, KNN algoritması DT algoritmasından istatistiksel olarak daha üstün performans göstermektedir.
# F1 skoru açısından ise, iki algoritma arasında anlamlı bir fark yoktur.
# Özgüllük açısından, KNN algoritması DT algoritmasından daha düşük performans göstermektedir.
#
# Zamanında teslimatlar bağlamında:
#
# KNN algoritmasının accuracy ve duyarlılık değerlerinin yüksek olması, zamanında teslimatları daha doğru bir şekilde tahmin edebildiğini gösterir. Bu, KNN algoritmasının müşteri memnuniyetini etkileyen bir faktör olarak zamanında teslimatları doğru bir şekilde tespit edebildiğine işaret eder.
# KNN algoritmasının özgüllük değerinin düşük olması, zamanında teslim edilmeyen teslimatları yanlışlıkla zamanında teslim edilmiş olarak tahmin etme olasılığının daha yüksek olduğunu gösterir. Bu durum, KNN algoritmasının iyileştirilmesi için değerlendirilmesi gereken bir noktadır.
#
# En iyi algoritmayı seçmek için:
#
# Accuracy, duyarlılık, özgüllük ve F1 skoru gibi metrikleri birlikte değerlendirmek gerekir.
# Modelin kullanım amacına göre bu metrikler arasında önceliklendirmeler yapılması gerekebilir.
# Örneğin, zamanında teslimatları daha doğru tahmin etmek öncelikliyse, accuracy ve duyarlılık değerleri daha yüksek olan KNN algoritması tercih edilebilir.
# Özgüllüğün de önemli olduğu durumlarda, özgüllük değerini iyileştirmeye yönelik çalışmalar yapılması gerekebilir.
